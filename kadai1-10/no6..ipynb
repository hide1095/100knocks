# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from skimage import io

img_orig = io.imread('https://yoyoyo-yo.github.io/Gasyori100knock/assets/imori_256x256.png')

plt.imshow(img_orig)
plt.show()

# %%
def decrease(img):
    img2 = img.flatten()
    for idx in range(len(img2)):
        if img2[idx] <64:
            img2[idx] = 32

        elif 64<=img2[idx]<128:
            img2[idx] = 96

        elif 128<=img2[idx]<192:
            img2[idx] =120

        else:
            pixel=224
    
    return img2.reshape(256,256,3)

# %%
img_anser = decrease(img_orig)
#print(img_anser)
plt.imshow(img_anser)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# anser 切り捨て除算を使う（余りを切り捨てる割り算の事）
def decrease_color(img):
	out = img.copy()

	out = (out // 64) * 64 + 32

	return out

# %%
img_anser = decrease_color(img_orig)
#print(img_anser)
plt.imshow(img_anser)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
