# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
#画像の読み込み
img = cv2.imread("/Users/hide/100knocks/test.jpeg")
# 画像の表示
plt.imshow(img)
plt.show()

# %%
# cv2のimreadはBGRの順
img = img[...,::-1]
plt.imshow(img)
plt.show()

# %%
from skimage import io

# %%
# skimageはurlから画像を読み込める
img = io.imread("https://yoyoyo-yo.github.io/Gasyori100knock/assets/imori_256x256.png")
plt.imshow(img)
plt.show()

# %%
print("imgの最小値:",img.min())
print("imgの最大値:",img.max())
# Out:
# imgの最小値: 5
# imgの最大値: 255

# %%
r = img[...,0]
g = img[...,1]
b = img[...,2]

plt.subplot(1,3,1) # 描画キャンパスを(n,m,i)n行m列に分解する
plt.title("r")
plt.imshow(r, cmap="gray")

plt.subplot(1,3,2)
plt.title("g")
plt.imshow(g,cmap="gray")

plt.subplot(1,3,3)
plt.title("b")
plt.imshow(b,cmap="gray")

plt.show()

# %%
# 画像のサイズ、なお画像はndarray形
img.shape
# Out:
# (256, 256, 3)

# %%
img.dtype
# 0~255
# Out:
# dtype('uint8')

# %%
_img = img.astype(np.float32)
_img.dtype
# Out:
# dtype('float32')

# %%
plt.imshow(_img)
plt.show()
# floatの時は0~1なら表示できるintは0~255
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
_img /= 255
plt.imshow(_img)
plt.show()

# %%
"""
一般的に画像を操作する時は、以下の方法がおすすめ
cv2.imread, io.imreadで読み込む
型を一度np.float32など小数点型に変換する
画像をいじる
画素が0未満のものは0, 255を超えたものは255に直す。（超重要）
型をnp.uint8に変換して表示・保存する この手順にすることをおすすめします。
"""
# Out:
# '\n一般的に画像を操作する時は、以下の方法がおすすめ\ncv2.imread, io.imreadで読み込む\n型を一度np.float32など小数点型に変換する\n画像をいじる\n画素が0未満のものは0, 255を超えたものは255に直す。（超重要）\n型をnp.uint8に変換して表示・保存する この手順にすることをおすすめします。\n'

# %%
# 画像のコピーはcopyを使う使わないとアドレスがコピーされるので変更しても同じ値になる
img2 = img.copy()

# %%
img[20, 30]
# Out:
# array([ 58,  75, 121], dtype=uint8)

# %%
img[20, 30, 1]
# Out:
# 75

# %%
img[20, 30:33]
# Out:
# array([[ 58,  75, 121],
#        [ 43,  70, 113],
#        [ 47,  72, 103]], dtype=uint8)

# %%
img2 = img.copy()
img2[:50, :50] = 0
plt.imshow(img2)
plt.show()

# %%
img2 = img.copy().astype(np.float32)
img2[60:160, 60:160, 2] = 260
img2 = img2.astype(np.uint8)
plt.imshow(img2)
# plt.show()
plt.savefig("yello.png")

# %%
cv2.imwrite('sample.png', img2)
# Out:
# True

# %%
plt.imshow(img)
plt.savefig('sample.png')

# %%
img3 = img.copy()
img3[:129,:129] = img[:129,:129,::-1]

# %%
plt.imshow(img3)
# plt.show()
plt.savefig("question.png")
